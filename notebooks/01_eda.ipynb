# %% [markdown]
# # Exploratory Data Analysis
# Retail demand data analysis before model training.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
# df = pd.read_csv('../data/raw/sales.csv')
# df.head()
